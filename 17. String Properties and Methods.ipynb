# %% [markdown]
# Immutability

# %%
name = "sam"

# %%
name[0] = "t"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f5204f53f153> in <module>
# ----> 1 name[0] = "t"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# strings do not support item assingment in python, we can't modify a part of this string using its index

# %%
#commented code that doesn't get run

# %%
name[1:]
# Out:
# 'am'

# %%
last letters = name[1:]
# Out:
#   File "<ipython-input-5-5fbeebd980f6>", line 1
#     last letters = name[1:]
#          ^
# SyntaxError: invalid syntax

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
#we just changed sam to pam using string concatenation

# %%
x = "My name is"

# %%
x + "calder"
# Out:
# 'My name iscalder'

# %%
x + " Calder"
# Out:
# 'My name is Calder'

# %%
x = x + " Calder"

# %%
x
# Out:
# 'My name is Calder'

# %%
#^string concatenation

# %%
letter = "z"

# %%
letter ^ 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-65add840c7cb> in <module>
# ----> 1 letter ^ 2
#
# TypeError: unsupported operand type(s) for ^: 'str' and 'int'

# %%
letter **2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-cec04fe3fb63> in <module>
# ----> 1 letter **2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
letter ** 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-35d3e4633689> in <module>
# ----> 1 letter ** 2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
#sleepy

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %%
#this isn't addition, this isn't concatenation

# %%
#this is a prime example where python isa flexible but too flexible, a user can input 2 and 3 to add and you can end up with 23 insted of 5

# %%
x = 'Hello World'

# %%
x.uppercase()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-76e1d832b5d4> in <module>
# ----> 1 x.uppercase()
#
# AttributeError: 'str' object has no attribute 'uppercase'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x
# Out:
# 'Hello World'

# %%
#when you call a function w/o executing it, it just tells you what the function does

# %%
x,lower
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-29733f02d48b> in <module>
# ----> 1 x,lower
#
# NameError: name 'lower' is not defined

# %%
x.lower
# Out:
# <function str.lower()>

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
#by default the split command splits on the whitespace

# %%
#you dont have to do that though

# %%
x.split("h")
# Out:
# ['Hello World']

# %%
x.split('o')
# Out:
# ['Hell', ' W', 'rld']
