# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
a + a + a
# Out:
# 30

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %%
type([bruh:e])
# Out:
#   File "<ipython-input-11-79dd2b81d474>", line 1
#     type([bruh:e])
#               ^
# SyntaxError: invalid syntax

# %%
my_income = 100

# %%
tax_rate = 0.1
my taxes = my_income * tax_rate
# Out:
#   File "<ipython-input-13-5e2560c58b1f>", line 2
#     my taxes = my_income * tax_rate
#        ^
# SyntaxError: invalid syntax

# %%
my_taxes = my_income * tax_rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0d78ddfeb4f9> in <module>
# ----> 1 my_taxes = my_income * tax_rate
#
# NameError: name 'tax_rate' is not defined

# %%
tax_rate = 0.1
my_taxes = my_income * tax_rate

# %%
print(my_taxes)
# Out:
# 10.0
