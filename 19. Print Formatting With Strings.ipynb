# %%
my_name = "Calder"
print("My Name is " + my_name)
# Out:
# My Name isCalder

# %%
my_name = "Calder"
print("My Name is " + my_name)
# Out:
# My Name is Calder

# %% [markdown]
# This is also known as string interpolation, sticking a variable into a string

# %% [markdown]
# {There are two other ways to do this: 1) .format() method 2)f-strings (formatted string literals)}

# %%
'string here {} then also {}'.format('something1','something2')
# Out:
# 'string here something1 then also something2'

# %% [markdown]
# FORMATTING WITH THE .format() METHOD

# %%
print('This is a string {}'.format('INSERTED'))
# Out:
# This is a string INSERTED

# %%
print('The {} {} {}'.format('fox', 'brown', 'quick'))
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print('The {0} {0} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The fox fox fox

# %%
print('The {q} {b} {f}' .format(f='fox', b ='brown', q = 'quick'))
# Out:
# The quick brown fox

# %%
print('The {f} {f} {f}' .format(f='fox', b ='brown', q = 'quick'))
# Out:
# The fox fox fox

# %% [markdown]
# Float formatting follows "{value:width.precision f}"|

# %%
result = 100/77

# %%
result
# Out:
# 1.2987012987012987

# %%
result = 100/777
print("The result was {}".format(result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r}".format(r = result))
# Out:
# The result was 0.1287001287001287

# %% [markdown]
# the full formatting below

# %%
print("The result was {r:1.3f}".format(r = result))
# Out:
# The result was 0.129

# %%
print("The number of L in the bottle is {r:1.2f} ".format(r=result))
# Out:
# The number of L in the bottle is 0.13

# %% [markdown]
# This is the newer stirng literal method tha tis opffered in newer versions of python. This skips the .format command and instead writes the "result" directly in the string

# %% [markdown]
# This is called fstring

# %%
name = 'Calder'

# %%
print(f'Hello, my name is {name}')
# Out:
# Hello, my name is Calder

# %%
name = "Bruh"
age = 2

# %%
print(f'{name} is {age} years old.')
# Out:
# Bruh is 2 years old.

# %% [markdown]
# Print Formatting FAQS
#
# 1.) I imported print from the __future__ module, now print isn't working. What happened?
#
# This is because once you import from the __future__ module in Python 2.7, a print statement will no longer work, and print must then use a print() function. Meaning that you must use
#
# print('Whatever you were going to print')
#
# or if you are using some formatting:
#
# print('This is a string with an {p}'.format(p='insert'))
#
# The __future__ module allows you to use Python3 functionality in a Python2 environment, but some functionality is overwritten (such as the print statement, or classic division when you import division).
#
# Since we are using Jupyter Notebooks, once you so the import, all cells will require the use if the print() function. You will have to restart Python or start a new notebook to regain the old functionality back.
