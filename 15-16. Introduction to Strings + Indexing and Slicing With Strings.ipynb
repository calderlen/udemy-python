# %%
Because strings are ordered sequences it means we can use indexing and slicing to grab sub-sections of the string
# Out:
#   File "<ipython-input-1-b532cf4a462e>", line 1
#     Because strings are ordered sequences it means we can use indexing and slicing to grab sub-sections of the string
#             ^
# SyntaxError: invalid syntax

# %%
"Because strings are ordered sequences it means we can use indexing and slicing to grab sub-sections of the string"
# Out:
# 'Because strings are ordered sequences it means we can use indexing and slicing to grab sub-sections of the string'

# %%
"examplestring"
# Out:
# 'examplestring'

# %%
"the white spaces count as characters"
# Out:
# 'the white spaces count as characters'

# %%
print()

# %%
print("examplestring")
# Out:
# examplestring

# %%
"hello world"
# Out:
# 'hello world'

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
print('hello \nworld')
# Out:
# hello
# world

# %%
print('hello \tworld')
# Out:
# hello 	world

# %%
len()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-adf3103c7c3e> in <module>
# ----> 1 len()
#
# TypeError: len() takes exactly one argument (0 given)

# %%
len("hello world")
# Out:
# 11

# %%
string = "hello world"

# %%
string[4]
# Out:
# 'o'

# %%
string[1]
# Out:
# 'e'

# %%
string[-1]
# Out:
# 'd'

# %%
string[0]
# Out:
# 'h'

# %%
string[1:1:5]
# Out:
# ''

# %%
string[1:5:1]
# Out:
# 'ello'

# %% [markdown]
# to slice a string it is [STARTING INDEX:ENDING INDEX:STEPS]

# %% [markdown]
# we can leave the steps out and it defaults to one. we can leave the first index out and it defaults to one step and starting at the first index, that would look like the following

# %%
string [:4]
# Out:
# 'hell'

# %%
string[::]
# Out:
# 'hello world'

# %%
string[::2]
# Out:
# 'hlowrd'

# %%
string[::-1]
# Out:
# 'dlrow olleh'

# %%
string[7:2:-1]
# Out:
# 'ow ol'
