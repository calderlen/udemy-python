# %% [markdown]
# Lists are ordered sequences that can hold a variety of object types
#
# They use [] brackets and commas to separate objects in the list
#
# Lists support indexing and slicing. Lists can be nested and have a variety of useful methods that can be called off of them

# %%
my_list = [1,2,3]

# %%
my_list = ['string',100,1.5]

# %%
print(my_list)
# Out:
# ['string', 100, 1.5]

# %%
my_list
# Out:
# ['string', 100, 1.5]

# %%
len(my_list)
# Out:
# 3

# %%
mylist = ['one', 'two', 'three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
anotherlist = ['four','five']

# %%
mylist = mylist + anotherlist

# %%
print(mylists)
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# all of this is very similar to a string, except we CAN change out certain elements of the list

# %%
mylist[0] = 'ONE'

# %%
mylist
# Out:
# ['ONE', 'two', 'three', 'four', 'five']

# %%
mylist.append('six')

# %%
mylist
# Out:
# ['ONE', 'two', 'three', 'four', 'five', 'six']

# %%
mylist.reverse()

# %%
mylist
# Out:
# ['six', 'five', 'four', 'three', 'two', 'ONE']

# %%
mylist.pop(0)
# Out:
# 'six'

# %%
mylist
# Out:
# ['five', 'four', 'three', 'two', 'ONE']

# %%
popped_item = mylist.pop(0)

# %%
popped_item
# Out:
# 'five'

# %%
new_list = ['a','e','x','b','c']
num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# the sort command does not return anything, instead when you call back the list again, it returns the new list

# %%
my_sorted_list = new_list.sort()

# %%
type(my_sorted_list)
# Out:
# NoneType

# %% [markdown]
# Instead what you have to do is

# %%
new_list.sort()
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.reverse()

# %%
num_list
# Out:
# [3, 8, 1, 4]

# %%
num_list.sort()

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]

# %% [markdown]
# Lists FAQ
#
# 1. How do I index a nested list? For example if I want to grab 2 from [1,1,[1,2]]?
#
# You would just add another set of brackets for indexing the nested list, for example: my_list[2][1] . We'll discover later on more nested objects and you will be quizzed on them later!
